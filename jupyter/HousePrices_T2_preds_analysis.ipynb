# %% [markdown]
# # HOUSE PRICES PREDICTION ANALYSIS

# %%
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import plotly.express as px
from datetime import datetime

# from pandas_profiling import ProfileReport as ppf
# %matplotlib inline

# %% [markdown]
# ## READ DATA

# %%
preds = pd.read_csv("../dai_predictions/HousePriceT2_855_AllCols.csv")
print(preds.shape)
preds.head()
# Out:
# (1459, 85)
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave    No      Reg
# 1  1462          20       RL         81.0    14267   Pave    No      IR1
# 2  1463          60       RL         74.0    13830   Pave    No      IR1
# 3  1464          60       RL         78.0     9978   Pave    No      IR1
# 4  1465         120       RL         43.0     5005   Pave    No      IR1
#
#   LandContour Utilities  ... OPEN_PORCH_SF_SQRT TOTAL_FLR_SQFT TOTAL_FLR_CNT  \
# 0         Lvl    AllPub  ...           0.000000            896             1
# 1         Lvl    AllPub  ...           6.000000           1329             1
# 2         Lvl    AllPub  ...           5.830952           1629             2
# 3         Lvl    AllPub  ...           6.000000           1604             2
# 4         HLS    AllPub  ...           9.055385           1280             1
#
# ...

# %% [markdown]
# training Set

# %%
train_df = pd.read_csv("../data/HousePrices_T2v3.csv")

# %% [markdown]
# ### Predicted Price Distribution

# %%
fig = px.histogram(preds, x="SalePrice", nbins=200)
fig.show()
# Out:
# <div>                            <div id="c714e4e8-87ae-43f4-a72c-1ff8b621d55b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c714e4e8-87ae-43f4-a72c-1ff8b621d55b")) {                    Plotly.newPlot(                        "c714e4e8-87ae-43f4-a72c-1ff8b621d55b",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "SalePrice=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 200, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [122778.2, 151484.31, 180369.84, 185819.98, 194169.0, 173471.95, 169368.86, 167427.03, 179825.67, 123393.75, 194865.66, 90020.32, 89931.9, 155005.5, 133516.34, 370372.62, 262416.56, 295152.1, 284
# ...

# %% [markdown]
# ### Historical Price Distribution

# %%
fig = px.histogram(train_df, x="SalePrice", nbins=200)
fig.show()
# Out:
# <div>                            <div id="f640a247-937b-4ea7-ab49-037f923bfb8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f640a247-937b-4ea7-ab49-037f923bfb8e")) {                    Plotly.newPlot(                        "f640a247-937b-4ea7-ab49-037f923bfb8e",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "SalePrice=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 200, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000, 129900, 118000, 129500, 345000, 144000, 279500, 157000, 132000, 149000, 90000, 159000, 139000, 325300, 139400, 230000, 129900, 154
# ...

# %%
preds.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %% [markdown]
# ### Less Than 300K

# %%
preds_lt300k = preds.loc[preds.SalePrice <= 300000].sort_values(by='SalePrice', ascending=False)[:30]

fig = px.scatter(preds_lt300k, x="TOTAL_FLR_SQFT", y="SalePrice", 
                 size="TOTAL_FLR_SQFT_PER_LOT_AREA", color="HouseStyle",
           hover_name="Street", 
                 log_x=False, 
                 size_max=60)
fig.show()
# Out:
# <div>                            <div id="4b091d5e-bc79-4c8e-b82a-331c1f9a743f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b091d5e-bc79-4c8e-b82a-331c1f9a743f")) {                    Plotly.newPlot(                        "4b091d5e-bc79-4c8e-b82a-331c1f9a743f",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>HouseStyle=2Story<br>TOTAL_FLR_SQFT=%{x}<br>SalePrice=%{y}<br>TOTAL_FLR_SQFT_PER_LOT_AREA=%{marker.size}<extra></extra>", "hovertext": ["Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave"], "legendgroup": "2Story", "marker": {"color": "#636efa", "size": [0.1916247642991829, 0.1538839322255873, 0.23404924044002096, 0.1750990906971322, 0.2807559728990848, 0.227000239788
# ...

# %%
preds_lt300k = preds.loc[preds.SalePrice >= 300000].sort_values(by='SalePrice', ascending=False)[:30]

fig = px.scatter(preds_lt300k, x="TOTAL_FLR_SQFT", y="SalePrice", 
                 size="OverallQual", color="HouseStyle",
           hover_name="Street", 
                 log_x=False, 
                 size_max=60)
fig.show()
# Out:
# <div>                            <div id="41b1ee44-49eb-4675-b5c8-1324065fe05d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41b1ee44-49eb-4675-b5c8-1324065fe05d")) {                    Plotly.newPlot(                        "41b1ee44-49eb-4675-b5c8-1324065fe05d",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>HouseStyle=2Story<br>TOTAL_FLR_SQFT=%{x}<br>SalePrice=%{y}<br>OverallQual=%{marker.size}<extra></extra>", "hovertext": ["Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave"], "legendgroup": "2Story", "marker": {"color": "#636efa", "size": [8, 8, 8, 8, 8, 7, 8, 8, 8, 7, 8, 7, 8], "sizemode": "area", "sizeref": 0.0025, "symbol": "circle"}, "mode": "markers", "name": "2St
# ...

# %%
preds_lt300k = preds.loc[preds.SalePrice >= 300000].sort_values(by='SalePrice', ascending=False)[:30]

fig = px.scatter(preds_lt300k, x="TOTAL_FLR_SQFT", y="SalePrice", 
                 size="LotArea", color="HouseStyle",
           hover_name="Street", 
                 log_x=False, 
                 size_max=60)
fig.show()
# Out:
# <div>                            <div id="105bd841-eb10-4d70-bad9-0a7dbfb84eee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("105bd841-eb10-4d70-bad9-0a7dbfb84eee")) {                    Plotly.newPlot(                        "105bd841-eb10-4d70-bad9-0a7dbfb84eee",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>HouseStyle=2Story<br>TOTAL_FLR_SQFT=%{x}<br>SalePrice=%{y}<br>LotArea=%{marker.size}<extra></extra>", "hovertext": ["Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave", "Pave"], "legendgroup": "2Story", "marker": {"color": "#636efa", "size": [17242, 13418, 18062, 13641, 14257, 16023, 9233, 16052, 13654, 13162, 10557, 16387, 15922], "sizemode": "area", "sizeref": 14.4372222222
# ...
